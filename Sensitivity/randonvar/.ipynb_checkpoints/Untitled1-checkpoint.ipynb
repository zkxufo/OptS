# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import torch
from torchvision.transforms import InterpolationMode
from torchvision import models, datasets, transforms
from torch.autograd.functional import jacobian
import math
from utils import *

# %%
def C(i):
    if i == 0:
        return 1/(2*math.sqrt(2))
    else:
        return 1/2
def getDCTCoef(size = (8,8)):
    DCT_coef = torch.zeros(size).double()
    for i in range(size[0]):
        for k in range(size[1]):
            C_i = C(i)
            DCT_coef[i,k]=C_i*math.cos((2*k+1)*i*math.pi/16)
    return DCT_coef
DCT_coef = getDCTCoef((8,8))

# %%
IDCT_coef = torch.inverse(DCT_coef)

# %%
resize8 = transforms.Resize((8, 8))
def process(blocks):
    return resize8(blocks[None,None,:])

# %%
blocks = torch.ones([17,17]).double()
t1 = jacobian(process, blocks)[0,0]
t1.shape
# Out:
# torch.Size([8, 8, 17, 17])

# %%
torch.sum(torch.abs(t1))
# Out:
# tensor(64., dtype=torch.float64)

# %%
t1[:,:,1,1]
# Out:
# tensor([[0.0156, 0.0781, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0781, 0.3906, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)

# %%
t1[:,:,3,2]
# Out:
# tensor([[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.2344, 0.2344, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0469, 0.0469, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000]],
#        dtype=torch.float64)

# %%
blocks = torch.ones([8,8]).double()
def IDCT(blocks):
    return IDCT_coef@(blocks[None,None,:])@IDCT_coef.transpose(1,0)

# %%
radblocks = torch.tensor(np.random.rand(8,8)).double()

# %%
DCTjacobianrad = jacobian(IDCT, radblocks)[0,0]

# %%
DCTjacobian = jacobian(IDCT, blocks)[0,0]

# %%
DCTjacobian.shape
# Out:
# torch.Size([8, 8, 8, 8])

# %%
DCTjacobianrad
# Out:
# tensor([[[[ 0.1250,  0.1734,  0.1633,  ...,  0.0982,  0.0676,  0.0345],
#           [ 0.1734,  0.2405,  0.2265,  ...,  0.1362,  0.0938,  0.0478],
#           [ 0.1633,  0.2265,  0.2134,  ...,  0.1283,  0.0884,  0.0451],
#           ...,
#           [ 0.0982,  0.1362,  0.1283,  ...,  0.0772,  0.0532,  0.0271],
#           [ 0.0676,  0.0938,  0.0884,  ...,  0.0532,  0.0366,  0.0187],
#           [ 0.0345,  0.0478,  0.0451,  ...,  0.0271,  0.0187,  0.0095]],
#
#          [[ 0.1250,  0.1470,  0.0676,  ..., -0.1734, -0.1633, -0.0982],
#           [ 0.1734,  0.2039,  0.0938,  ..., -0.2405, -0.2265, -0.1362],
#           [ 0.1633,  0.1920,  0.0884,  ..., -0.2265, -0.2134, -0.1283],
#           ...,
#           [ 0.0982,  0.1155,  0.0532,  ..., -0.1362, -0.1283, -0.0772],
#           [ 0.0676,  0.0795,  0.0366,  ..., -0.0938, -0.0884, -0.0532],
#           [ 0.0345,  0.0406,  0.0187,  ..., -0.0478, -0.0451, -0.0271]],
#
#          [[ 0.1250,  0.0982, -0.0676,  ...,  0.0345,  0.1633,  0.1470],
#           [ 0.1734,  0.1362, -0.0938,  ...,  0.0478,  0.2265,  0.2039],
#           [ 0.1633,  0.1283, -0.0884,  ...,  0.0451,  0.2134,  0.1920],
#           ...,
#           [ 0.0982,  0.0772, -0.0532,  ...,  0.0271,  0.1283,  0.1155],
#           [ 0.0676,  0.0532, -0.0366,  ...,  0.0187,  0.0884,  0.0795],
#           [ 0.0345,  0.0271, -0.0187,  ...,  0.0095,  0.0451,  0.0406]],
#
#          ...,
#
#          [[ 0.1250, -0.0982, -0.0676,  ..., -0.0345,  0.1633, -0.1470],
#           
],
#
#          [[ 0.1250,  0.0982, -0.0676,  ...,  0.0345,  0.1633,  0.1470],
#           [ 0.1470,  0.1155, -0.0795,  ...,  0.0406,  0.1920,  0.1728],
#           [ 0.0676,  0.0532, -0.0366,  ...,  0.0187,  0.0884,  0.0795],
#           ...,
#           [-0.1734, -0.1362,  0.0938,  ..., -0.0478, -0.2265, -0.2039],
#           [-0.1633, -0.1283,  0.0884,  ..., -0.0451, -0.2134, -0.1920],
#           [-0.0982, -0.0772,  0.0532,  ..., -0.0271, -0.1283, -0.1155]],
#
#          ...,
#
#          [[ 0.1250, -0.0982, -0.0676,  ..., -0.0345,  0.1633, -0.1470],
#           [ 0.1470, -0.1155, -0.0795,  ..., -0.0406,  0.1920, -0.1728],
#           [ 0.0676, -0.0532, -0.0366,  ..., -0.0187,  0.0884, -0.0795],
#           ...,
#           [-0.1734,  0.1362,  0.0938,  ...,  0.0478, -0.2265,  0.2039],
#           [-0.1633,  0.1283,  0.0884,  ...,  0.0451, -0.2134,  0.1920],
#           [-0.0982,  0.0772,  0.0532,  ...,  0.0271, -0.1283,  0.1155]],
#
#          [[ 0.1250, -0.1470,  0.0676,  ...,  0.1734, -0.1633,  0.0982],
#           [ 0.1470, -0.1728,  0.0795,  ...,  0.2039, -0.1920,  0.1155],
#           [ 0.0676, -0.0795,  0.0366,  ...,  0.0938, -0.0884,  0.0532],
#           ...,
#           [-0.1734,  0.2039, -0.0938,  ..., -0.2405,  0.2265, -0.1362],
#           [-0.1633,  0.1920, -0.0884,  ..., -0.2265,  0.2134, -0.1283],
#           [-0.0982,  0.1155, -0.0532,  ..., -0.1362,  0.1283, -0.0772]],
#
#          [[ 0.1250, -0.1734,  0.1633,  ..., -0.0982,  0.0676, -0.0345],
#           [ 0.1470, -0.2039,  0.1920,  ..., -0.1155,  0.0795, -0.0406],
#           [ 0.0676, -0.0938,  0.0884,  ..., -0.0532,  0.0366, -0.0187],
#           ...,
#           [-0.1734,  0.2405, -0.2265,  ...,  0.1362, -0.0938,  0.0478],
#           [-0.1633,  0.2265, -0.2134,  ...,  0.1283, -0.0884,  0.0451],
#           [-0.0982,  0.1362, -0.1283,  ...,  0.0772, -0.0532,  0.0271]]],
#
#
#         [[[ 0.1250,  0.1734,  0.1633,  ...,  0.0982,  0.0676,  0.0345],
#           [ 0.0982,  0.1362,  0.1283,  ...,  0.0772,  0.0532,  0.0271],
#           [-0.0676, -0.0938, -0.0884,  ..., -0.0532, -0.0366, -0.0187],
#           ...,
#           [ 0.0345,  0.0478,  0.0451,  ...,  0.0271,  0.0187,  0.0095],
#           [ 0.1633,  0.2265,  0.2134,  ...,  0.1283,  0.0884,  0.0451],
#           [ 0.1470,  0.2039,  0.1920,  ...,  0.1155,  0.0795,  0.0406]],
#
#          [[ 0.1250,  0.1470,  0.0676,  ..., -0.1734, -0.1633, -0.0982],
#           [ 0.0982,  0.1155,  0.0532,  ..., -0.1362, -0.1283, -0.0772],
#           [-0.0676, -0.0795, -0.0366,  ...,  0.0938,  0.0884,  0.0532],
#           ...,
#           [ 0.0345,  0.0406,  0.0187,  ..., -0.0478, -0.0451, -0.0271],
#           [ 0.1633,  0.1920,  0.0884,  ..., -0.2265, -0.2134, -0.1283],
#           [ 0.1470,  0.1728,  0.0795,  ..., -0.2039, -0.1920, -0.1155]],
#
#          [[ 0.1250,  0.0982, -0.0676,  ...,  0.0345,  0.1633,  0.1470],
#           [ 0.0982,  0.0772, -0.0532,  ...,  0.0271,  0.1283,  0.1155],
#           [-0.0676, -0.0532,  0.0366,  ..., -0.0187, -0.0884, -0.0795],
#           ...,
#           [ 0.0345,  0.0271, -0.0187,  ...,  0.0095,  0.0451,  0.0406],
#           [ 0.1633,  0.1283, -0.0884,  ...,  0.0451,  0.2134,  0.1920],
#           [ 0.1470,  0.1155, -0.0795,  ...,  0.0406,  0.1920,  0.1728]],
#
#          ...,
#
#          [[ 0.1250, -0.0982, -0.0676,  ..., -0.0345,  0.1633, -0.1470],
#           [ 0.0982, -0.0772, -0.0532,  ..., -0.0271,  0.1283, -0.1155],
#           [-0.0676,  0.0532,  0.0366,  ...,  0.0187, -0.0884,  0.0795],
#           ...,
#           [ 0.0345, -0.0271, -0.0187,  ..., -0.0095,  0.0451, -0.0406],
#           [ 0.1633, -0.1283, -0.0884,  ..., -0.0451,  0.2134, -0.1920],
#           [ 0.1470, -0.1155, -0.0795,  ..., -0.0406,  0.1920, -0.1728]],
#
#          [[ 0.1250, -0.1470,  0.0676,  ...,  0.1734, -0.1633,  0.0982],
#           [ 0.0982, -0.1155,  0.0532,  ...,  0.1362, -0.1283,  0.0772],
#           [-0.0676,  0.0795, -0.0366,  ..., -0.0938,  0.0884, -0.0532],
#           ...,
#           [ 0.0345, -0.0406,  0.0187,  ...,  0.0478, -0.0451,  0.0271],
#           [ 0.1633, -0.1920,  0.0884,  ...,  0.2265, -0.2134,  0.1283],
#           [ 0.1470, -0.1728,  0.0795,  ...,  0.2039, -0.1920,  0.1155]],
#
#          [[ 0.1250, -0.1734,  0.1633,  ..., -0.0982,  0.0676, -0.0345],
#           [ 0.0982, -0.1362,  0.1283,  ..., -0.0772,  0.0532, -0.0271],
#           [-0.0676,  0.0938, -0.0884,  ...,  0.0532, -0.0366,  0.0187],
#           ...,
#           [ 0.0345, -0.0478,  0.0451,  ..., -0.0271,  0.0187, -0.0095],
#           [ 0.1633, -0.2265,  0.2134,  ..., -0.1283,  0.0884, -0.0451],
#           [ 0.1470, -0.2039,  0.1920,  ..., -0.1155,  0.0795, -0.0406]]],
#
#
#         ...,
#
#
#         [[[ 0.1250,  0.1734,  0.1633,  ...,  0.0982,  0.0676,  0.0345],
#           [-0.0982, -0.1362, -0.1283,  ..., -0.0772, -0.0532, -0.0271],
#           [-0.0676, -0.0938, -0.0884,  ..., -0.0532, -0.0366, -0.0187],
#           ...,
#           [-0.0345, -0.0478, -0.0451,  ..., -0.0271, -0.0187, -0.0095],
#           [ 0.1633,  0.2265,  0.2134,  ...,  0.1283,  0.0884,  0.0451],
#           [-0.1470, -0.2039, -0.1920,  ..., -0.1155, -0.0795, -0.0406]],
#
#          [[ 0.1250,  0.1470,  0.0676,  ..., -0.1734, -0.1633, -0.0982],
#           [-0.0982, -0.1155, -0.0532,  ...,  0.1362,  0.1283,  0.0772],
#           [-0.0676, -0.0795, -0.0366,  ...,  0.0938,  0.0884,  0.0532],
#           ...,
#           [-0.0345, -0.0406, -0.0187,  ...,  0.0478,  0.0451,  0.0271],
#           [ 0.1633,  0.1920,  0.0884,  ..., -0.2265, -0.2134, -0.1283],
#           [-0.1470, -0.1728, -0.0795,  ...,  0.2039,  0.1920,  0.1155]],
#
#          [[ 0.1250,  0.0982, -0.0676,  ...,  0.0345,  0.1633,  0.1470],
#           [-0.0982, -0.0772,  0.0532,  ..., -0.0271, -0.1283, -0.1155],
#           [-0.0676, -0.0532,  0.0366,  ..., -0.0187, -0.0884, -0.0795],
#           ...,
#           [-0.0345, -0.0271,  0.0187,  ..., -0.0095, -0.0451, -0.0406],
#           [ 0.1633,  0.1283, -0.0884,  ...,  0.0451,  0.2134,  0.1920],
#           [-0.1470, -0.1155,  0.0795,  ..., -0.0406, -0.1920, -0.1728]],
#
#          ...,
#
#          [[ 0.1250, -0.0982, -0.0676,  ..., -0.0345,  0.1633, -0.1470],
#           [-0.0982,  0.0772,  0.0532,  ...,  0.0271, -0.1283,  0.1155],
#           [-0.0676,  0.0532,  0.0366,  ...,  0.0187, -0.0884,  0.0795],
#           ...,
#           [-0.0345,  0.0271,  0.0187,  ...,  0.0095, -0.0451,  0.0406],
#           [ 0.1633, -0.1283, -0.0884,  ..., -0.0451,  0.2134, -0.1920],
#           [-0.1470,  0.1155,  0.0795,  ...,  0.0406, -0.1920,  0.1728]],
#
#          [[ 0.1250, -0.1470,  0.0676,  ...,  0.1734, -0.1633,  0.0982],
#           [-0.0982,  0.1155, -0.0532,  ..., -0.1362,  0.1283, -0.0772],
#           [-0.0676,  0.0795, -0.0366,  ..., -0.0938,  0.0884, -0.0532],
#           ...,
#           [-0.0345,  0.0406, -0.0187,  ..., -0.0478,  0.0451, -0.0271],
#           [ 0.1633, -0.1920,  0.0884,  ...,  0.2265, -0.2134,  0.1283],
#           [-0.1470,  0.1728, -0.0795,  ..., -0.2039,  0.1920, -0.1155]],
#
#          [[ 0.1250, -0.1734,  0.1633,  ..., -0.0982,  0.0676, -0.0345],
#           [-0.0982,  0.1362, -0.1283,  ...,  0.0772, -0.0532,  0.0271],
#           [-0.0676,  0.0938, -0.0884,  ...,  0.0532, -0.0366,  0.0187],
#           ...,
#           [-0.0345,  0.0478, -0.0451,  ...,  0.0271, -0.0187,  0.0095],
#           [ 0.1633, -0.2265,  0.2134,  ..., -0.1283,  0.0884, -0.0451],
#           [-0.1470,  0.2039, -0.1920,  ...,  0.1155, -0.0795,  0.0406]]],
#
#
#         [[[ 0.1250,  0.1734,  0.1633,  ...,  0.0982,  0.0676,  0.0345],
#           [-0.1470, -0.2039, -0.1920,  ..., -0.1155, -0.0795, -0.0406],
#           [ 0.0676,  0.0938,  0.0884,  ...,  0.0532,  0.0366,  0.0187],
#           ...,
#           [ 0.1734,  0.2405,  0.2265,  ...,  0.1362,  0.0938,  0.0478],
#           [-0.1633, -0.2265, -0.2134,  ..., -0.1283, -0.0884, -0.0451],
#           [ 0.0982,  0.1362,  0.1283,  ...,  0.0772,  0.0532,  0.0271]],
#
#          [[ 0.1250,  0.1470,  0.0676,  ..., -0.1734, -0.1633, -0.0982],
#           [-0.1470, -0.1728, -0.0795,  ...,  0.2039,  0.1920,  0.1155],
#           [ 0.0676,  0.0795,  0.0366,  ..., -0.0938, -0.0884, -0.0532],
#           ...,
#           [ 0.1734,  0.2039,  0.0938,  ..., -0.2405, -0.2265, -0.1362],
#           [-0.1633, -0.1920, -0.0884,  ...,  0.2265,  0.2134,  0.1283],
#           [ 0.0982,  0.1155,  0.0532,  ..., -0.1362, -0.1283, -0.0772]],
#
#          [[ 0.1250,  0.0982, -0.0676,  ...,  0.0345,  0.1633,  0.1470],
#           [-0.1470, -0.1155,  0.0795,  ..., -0.0406, -0.1920, -0.1728],
#           [ 0.0676,  0.0532, -0.0366,  ...,  0.0187,  0.0884,  0.0795],
#           ...,
#           [ 0.1734,  0.1362, -0.0938,  ...,  0.0478,  0.2265,  0.2039],
#           [-0.1633, -0.1283,  0.0884,  ..., -0.0451, -0.2134, -0.1920],
#           [ 0.0982,  0.0772, -0.0532,  ...,  0.0271,  0.1283,  0.1155]],
#
#          ...,
#
#          [[ 0.1250, -0.0982, -0.0676,  ..., -0.0345,  0.1633, -0.1470],
#           [-0.1470,  0.1155,  0.0795,  ...,  0.0406, -0.1920,  0.1728],
#           [ 0.0676, -0.0532, -0.0366,  ..., -0.0187,  0.0884, -0.0795],
#           ...,
#           [ 0.1734, -0.1362, -0.0938,  ..., -0.0478,  0.2265, -0.2039],
#           [-0.1633,  0.1283,  0.0884,  ...,  0.0451, -0.2134,  0.1920],
#           [ 0.0982, -0.0772, -0.0532,  ..., -0.0271,  0.1283, -0.1155]],
#
#          [[ 0.1250, -0.1470,  0.0676,  ...,  0.1734, -0.1633,  0.0982],
#           [-0.1470,  0.1728, -0.0795,  ..., -0.2039,  0.1920, -0.1155],
#           [ 0.0676, -0.0795,  0.0366,  ...,  0.0938, -0.0884,  0.0532],
#           ...,
#           [ 0.1734, -0.2039,  0.0938,  ...,  0.2405, -0.2265,  0.1362],
#           [-0.1633,  0.1920, -0.0884,  ..., -0.2265,  0.2134, -0.1283],
#           [ 0.0982, -0.1155,  0.0532,  ...,  0.1362, -0.1283,  0.0772]],
#
#          [[ 0.1250, -0.1734,  0.1633,  ..., -0.0982,  0.0676, -0.0345],
#           [-0.1470,  0.2039, -0.1920,  ...,  0.1155, -0.0795,  0.0406],
#           [ 0.0676, -0.0938,  0.0884,  ..., -0.0532,  0.0366, -0.0187],
#           ...,
#           [ 0.1734, -0.2405,  0.2265,  ..., -0.1362,  0.0938, -0.0478],
#           [-0.1633,  0.2265, -0.2134,  ...,  0.1283, -0.0884,  0.0451],
#           [ 0.0982, -0.1362,  0.1283,  ..., -0.0772,  0.0532, -0.0271]]],
#
#
#         [[[ 0.1250,  0.1734,  0.1633,  ...,  0.0982,  0.0676,  0.0345],
#           [-0.1734, -0.2405, -0.2265,  ..., -0.1362, -0.0938, -0.0478],
#           [ 0.1633,  0.2265,  0.2134,  ...,  0.1283,  0.0884,  0.0451],
#           ...,
#           [-0.0982, -0.1362, -0.1283,  ..., -0.0772, -0.0532, -0.0271],
#           [ 0.0676,  0.0938,  0.0884,  ...,  0.0532,  0.0366,  0.0187],
#           [-0.0345, -0.0478, -0.0451,  ..., -0.0271, -0.0187, -0.0095]],
#
#          [[ 0.1250,  0.1470,  0.0676,  ..., -0.1734, -0.1633, -0.0982],
#           [-0.1734, -0.2039, -0.0938,  ...,  0.2405,  0.2265,  0.1362],
#           [ 0.1633,  0.1920,  0.0884,  ..., -0.2265, -0.2134, -0.1283],
#           ...,
#           [-0.0982, -0.1155, -0.0532,  ...,  0.1362,  0.1283,  0.0772],
#           [ 0.0676,  0.0795,  0.0366,  ..., -0.0938, -0.0884, -0.0532],
#           [-0.0345, -0.0406, -0.0187,  ...,  0.0478,  0.0451,  0.0271]],
#
#          [[ 0.1250,  0.0982, -0.0676,  ...,  0.0345,  0.1633,  0.1470],
#           [-0.1734, -0.1362,  0.0938,  ..., -0.0478, -0.2265, -0.2039],
#           [ 0.1633,  0.1283, -0.0884,  ...,  0.0451,  0.2134,  0.1920],
#           ...,
#           [-0.0982, -0.0772,  0.0532,  ..., -0.0271, -0.1283, -0.1155],
#           [ 0.0676,  0.0532, -0.0366,  ...,  0.0187,  0.0884,  0.0795],
#           [-0.0345, -0.0271,  0.0187,  ..., -0.0095, -0.0451, -0.0406]],
#
#          ...,
#
#          [[ 0.1250, -0.0982, -0.0676,  ..., -0.0345,  0.1633, -0.1470],
#           [-0.1734,  0.1362,  0.0938,  ...,  0.0478, -0.2265,  0.2039],
#           [ 0.1633, -0.1283, -0.0884,  ..., -0.0451,  0.2134, -0.1920],
#           ...,
#           [-0.0982,  0.0772,  0.0532,  ...,  0.0271, -0.1283,  0.1155],
#           [ 0.0676, -0.0532, -0.0366,  ..., -0.0187,  0.0884, -0.0795],
#           [-0.0345,  0.0271,  0.0187,  ...,  0.0095, -0.0451,  0.0406]],
#
#          [[ 0.1250, -0.1470,  0.0676,  ...,  0.1734, -0.1633,  0.0982],
#           [-0.1734,  0.2039, -0.0938,  ..., -0.2405,  0.2265, -0.1362],
#           [ 0.1633, -0.1920,  0.0884,  ...,  0.2265, -0.2134,  0.1283],
#           ...,
#           [-0.0982,  0.1155, -0.0532,  ..., -0.1362,  0.1283, -0.0772],
#           [ 0.0676, -0.0795,  0.0366,  ...,  0.0938, -0.0884,  0.0532],
#           [-0.0345,  0.0406, -0.0187,  ..., -0.0478,  0.0451, -0.0271]],
#
#          [[ 0.1250, -0.1734,  0.1633,  ..., -0.0982,  0.0676, -0.0345],
#           [-0.1734,  0.2405, -0.2265,  ...,  0.1362, -0.0938,  0.0478],
#           [ 0.1633, -0.2265,  0.2134,  ..., -0.1283,  0.0884, -0.0451],
#           ...,
#           [-0.0982,  0.1362, -0.1283,  ...,  0.0772, -0.0532,  0.0271],
#           [ 0.0676, -0.0938,  0.0884,  ..., -0.0532,  0.0366, -0.0187],
#           [-0.0345,  0.0478, -0.0451,  ...,  0.0271, -0.0187,  0.0095]]]],
#        dtype=torch.float64)

# %%
t1.shape
# Out:
# torch.Size([1, 1, 8, 8, 9, 9])

# %%
a = square_to_zigzag(torch.abs((DCTjacobian[0,0]@blocks)[:,:,1,2]))

# %%
plt.plot(a.cpu().numpy())

# %%
DCTjacobian[0,0].shape
# Out:
# torch.Size([8, 8, 8, 8])

# %%
resize224 = transforms.Resize((224,224))

# %%
import torch.autograd
x = torch.tensor(np.random.rand(1,1,500,500))
x.requires_grad = True
y = resize224(x)
y.backward(gradient=torch.tensor(np.random.rand(1,1,224,224))/2)
x.grad.shape
# Out:
# torch.Size([1, 1, 500, 500])

# %%
block_dct,block_idct,square_to_zigzag,quantizationTable
# Out:
# <function utils.block_dct(blocks: torch.Tensor) -> torch.Tensor>

# %%
img = torch.ones(1,14,14)

# %%
img.shape
# Out:
# torch.Size([1, 14, 14])

# %%
imgAddAxis = img[None,:]
img_shape = img.shape[-2:]
DCTBlock = block_dct(blockify(imgAddAxis, 8))
DCTBlock.requires_grad = True
RecoverImg = deblockify(block_idct(DCTBlock), (img_shape[0], img_shape[1]))
RecoverSizeImg = resize224(RecoverImg)
RecoverSizeImg.backward(gradient=torch.tensor(np.zeros([1,8,8,8])))
DCTBlock.grad
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [134], in <cell line: 7>()
#       5 RecoverImg = deblockify(block_idct(DCTBlock), (img_shape[0], img_shape[1]))
#       6 RecoverSizeImg = resize224(RecoverImg)
# ----> 7 RecoverSizeImg.backward(gradient=torch.tensor(np.zeros([1,8,8,8])))
#       8 DCTBlock.grad
#
# File ~/.local/lib/python3.8/site-packages/torch/_tensor.py:255, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     246 if has_torch_function_unary(self):
#     247     return handle_torch_function(
#     248         Tensor.backward,
#     249         (self,),
#    (...)
#     253         create_graph=create_graph,
#     254         inputs=inputs)
# --> 255 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~/.local/lib/python3.8/site-packages/torch/autograd/__init__.py:143, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     139 inputs = (inputs,) if isinstance(inputs, torch.Tensor) else \
#     140     tuple(inputs) if inputs is not None else tuple()
#     142 grad_tensors_ = _tensor_or_tensors_to_tuple(grad_tensors, len(tensors))
# --> 143 grad_tensors_ = _make_grads(tensors, grad_tensors_)
#     144 if retain_graph is None:
#     145     retain_graph = create_graph
#
# File ~/.local/lib/python3.8/site-packages/torch/autograd/__init__.py:33, in _make_grads(outputs, grads)
#      31 if isinstance(grad, torch.Tensor):
#      32     if not out.shape == grad.shape:
# ---> 33         raise RuntimeError("Mismatch in shape: grad_output["
#      34                            + str(grads.index(grad)) + "] has a shape of "
#      35                            + str(grad.shape) + " and output["
#      36                            + str(outputs.index(out)) + "] has a shape of "
#      37                            + str(out.shape) + ".")
#      38     if out.dtype.is_complex != grad.dtype.is_complex:
#      39         raise RuntimeError("For complex Tensors, both grad_output and output"
#      40                            " are required to have the same dtype."
#      41                            " Mismatch in dtype: grad_output["
#    (...)
#      44                            + str(outputs.index(out)) + "] has a dtype of "
#      45                            + str(out.dtype) + ".")
#
# RuntimeError: Mismatch in shape: grad_output[0] has a shape of torch.Size([1, 8, 8, 8]) and output[0] has a shape of torch.Size([1, 1, 224, 224]).

# %%
radblocks = torch.tensor(np.random.rand(16,16)).double()

# %%
resize8 = transforms.Resize((8, 8))
def process(DCTblocks):
    blockSize = DCTblocks.shape
    DCT_coef = getDCTCoef(blockSize)
    IDCT_coef = torch.inverse(DCT_coef)
    blocks = IDCT_coef@DCTblocks@(IDCT_coef.transpose(1,0))
    resizeBlock = resize8(blocks[None,None,:])
    DCT_coef8 = getDCTCoef((8,8))
    return DCT_coef8@resizeBlock@(DCT_coef8.transpose(1,0))

# %%
J = jacobian(process,radblocks)
J.shape
# Out:
# torch.Size([1, 1, 8, 8, 16, 16])

# %%
J[0,0,:,:,2,3]
# Out:
# tensor([[-5.0688e-04, -8.8203e+11, -6.7922e-04,  3.7110e+12,  2.7819e-03,
#           7.8660e+11,  1.0004e-02, -5.2280e+11],
#         [-1.0343e+12, -1.6706e+27, -1.0195e+12,  5.1304e+27,  4.9170e+12,
#           1.1292e+27,  1.1554e+13, -8.4580e+26],
#         [ 2.7816e+11,  3.3105e+12,  1.6315e+11, -1.1684e+13, -2.0819e+11,
#          -1.2935e+12,  8.3990e+11,  7.8998e+10],
#         [-2.7948e+12, -1.4645e+28, -8.9152e+12,  4.4975e+28,  3.1072e+13,
#           9.8985e+27,  9.9765e+13, -7.4145e+27],
#         [ 7.6600e+10, -2.4039e+13, -1.2610e+11,  8.6279e+13,  3.0704e+12,
#           1.7427e+13,  3.7258e+11, -1.3120e+13],
#         [ 2.2274e+12,  7.4205e+27,  3.9254e+12, -2.2788e+28, -1.6118e+13,
#          -5.0154e+27, -5.0415e+13,  3.7568e+27],
#         [ 6.2787e+11, -3.2635e+12, -5.9060e+11, -2.6070e+12, -5.0365e+11,
#          -1.3072e+12,  8.9976e+11, -1.1841e+12],
#         [ 3.8614e+12,  1.1233e+28,  4.4832e+12, -3.4495e+28, -2.2056e+13,
#          -7.5921e+27, -7.5192e+13,  5.6869e+27]], dtype=torch.float64)

# %%
J[0,0,:,:,2,3]
